# %% [markdown]
# # ANÁLISIS OBRAS

# %% [markdown]
# 📊📈 **Para realizar un pequeño análisis de las obras se realizarán un par de gráficos.**
#
# 1️⃣ En el primero, se muestra cual es aproximadamente la media de obras escritas por un autor, es decir, cuantas obras es más común que realice un mismo autor. Además, esta información vendrá acompañada de un describe donde se pueden observar el número medio de obras, el número máximo o el mínimo entre otos datos de interés.
#
# 2️⃣ Por otro lado, un gráfico que aporta información sobre el número de obras perteneciente a cada género. De este modo, es posible analizar los géneros que poseen un mayor número de obras.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
art = pd.read_csv('../data/artistas_revoluciones.csv', index_col = 0)
art.head(2)
# Out:
#                   name        years                         genre nationality  \
# id
# 0    Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1   Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
#
#                                                   bio  \
# id
# 0   Amedeo Clemente Modigliani  was an Italian Jew...
# 1   Wassily Wassilyevich Kandinsky   was a Russian...
#
#                                          wikipedia  paintings  year_of_birth  \
# id
# 0   http://en.wikipedia.org/wiki/Amedeo_Modigliani        193           1884
# 1   http://en.wikipedia.org/wiki/Wassily_Kandinsky         88           1866
#
#     year_of_death               revolución
# id
# 0            1920  Revolución rusa de 1905
# 1            1944       Revolución de 1868

# %%
art.describe()
# Out:
#         paintings  year_of_birth  year_of_death
# count   50.000000      50.000000      50.000000
# mean   168.920000    1737.820000    1802.600000
# std    157.451105     187.213693     188.773377
# min     24.000000    1266.000000    1337.000000
# 25%     81.000000    1572.500000    1620.500000
# 50%    123.000000    1839.500000    1902.000000
# 75%    191.750000    1871.250000    1943.000000
# max    877.000000    1928.000000    1989.000000

# %%
obras = sns.displot(art.paintings,
            color='navy', 
            edgecolor = "black", 
            bins= 50, 
            kde=True, 
            height = 10,
            aspect =0.8)

obras.set(title = "Total número de obras más común")
obras.savefig('../images/Total número de obras más común.png');

# %% [markdown]
# 🤔🤓 De este modo, podemos apreciar que la mayoría de autores escriben menos de 200 obras. Junto a la información aportada por el describe, podemos afirmar que 191 obras se posiciona en el tercer cuartil, lo que nos indica que un 75% de los autores han realizado 191 obras o menos.

# %%
plt.rcParams["figure.figsize"] = (20, 8)
genres = art['genre']


obras_gen = sns.lineplot(data= art, x="genre", y="paintings",
                    color = "black",
                    marker = 'o',
                    markersize = 8,
                    linewidth = 2);

obras_gen.set_facecolor("white")
obras_gen.spines['bottom'].set_color('black') 
obras_gen.spines['top'].set_color('white') 
obras_gen.spines['right'].set_color('white')
obras_gen.spines['left'].set_color('black')

plt.ylim(0,500)

obras_gen.set_xticklabels(genres, rotation = 55)

plt.title("Número de obras por género")
                     
plt.savefig("../images/Número de obras por género.png")
    
plt.show();
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_19068/524169115.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   obras_gen.set_xticklabels(genres, rotation = 55)

# %% [markdown]
# 🤨🧐 En este caso, podemos observar como el cubirmo, en primer lugar, y el realismo social, en segundo, destacan como los géneros con el mayor número de obras. Por su parte, el impresionismo destaca por el poco número de obras.
